# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("../data_files/sentences.csv")
df.head()
# Out:
#    defendant  sentence                 Name      Name (sortable)  \
# 0       5303      5501  Reno [No Last Name]  [no last name] reno
# 1       5303      5502  Reno [No Last Name]  [no last name] reno
# 2       5304      5503     Joe Henry Abbott           abbott joe
# 3       5305      5504          Dane Abdool          abdool dane
# 4       6433      7392    Jalil Abdul-Kabir    abdul-kabir jalil
#
#            Aliases Gender  Races Jurisdiction State Abbreviation  \
# 0  Harold R. Memro   Male  White   California                 CA
# 1  Harold R. Memro   Male  White   California                 CA
# 2              NaN   Male  Black   California                 CA
# 3              NaN   Male  White      Florida                 FL
# 4  Ted Calvin Cole   Male  White        Texas                 TX
#
#         Sub Jurisdiction                   County and State Region    Year  \
# 0     Los Angeles County     Los Angeles County, California   West  1979.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9940 entries, 0 to 9939
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   defendant                  9940 non-null   int64
#  1   sentence                   9940 non-null   int64
#  2   Name                       9940 non-null   str
#  3   Name (sortable)            9940 non-null   str
#  4   Aliases                    304 non-null    str
#  5   Gender                     9939 non-null   str
#  6   Races                      9935 non-null   str
#  7   Jurisdiction               9940 non-null   str
#  8   State Abbreviation         9831 non-null   str
#  9   Sub Jurisdiction           9938 non-null   str
#  10  County and State           9940 non-null   str
#  11  Region                     9919 non-null   str
#  12  Year                       9931 non-null   float64
#  13  Multi-sentence identifier  1890 non-null   str
# ...

# %%
df = df.sort_values(by='Year')
df.head()
# Out:
#       defendant  sentence                    Name    Name (sortable) Aliases  \
# 9273      11400     15805   Junior Lee Washington  washington junior     NaN
# 8605      10943     15058  Vernon Charles Talbert     talbert vernon     NaN
# 9291      11414     15829  Harold Legusta Watkins     watkins harold     NaN
# 710        5769      6259   Johnny James Blackmon    blackmon johnny     NaN
# 2409       6890      8162          Howard Douglas     douglas howard     NaN
#
#      Gender  Races    Jurisdiction State Abbreviation Sub Jurisdiction  \
# 9273   Male  Black  North Carolina                 NC      Hoke County
# 8605   Male  White  North Carolina                 NC     Rowan County
# 9291   Male  Black  North Carolina                 NC  Richmond County
# 710    Male  Black  North Carolina                 NC     Union County
# 2409   Male  White         Florida                 FL      Polk County
#
#                      County and State Region    Year  \
# ...

# %%
df.columns
# Out:
# Index(['defendant', 'sentence', 'Name', 'Name (sortable)', 'Aliases', 'Gender',
#        'Races', 'Jurisdiction', 'State Abbreviation', 'Sub Jurisdiction',
#        'County and State', 'Region', 'Year', 'Multi-sentence identifier',
#        'Outcome of Sentence', 'Current Case Status'],
#       dtype='str')

# %%
df.tail()
# Out:
#       defendant  sentence               Name Name (sortable) Aliases Gender  \
# 5049       8594     11069   Johnny D. Lackey   lackey johnny     NaN   Male
# 5253       8726     16613    David Lee Lewis     lewis david     NaN   Male
# 6980       9880     13240  James F. Pope III      pope james     NaN   Male
# 6981       9880     16774  James F. Pope III      pope james     NaN   Male
# 8152      10664     16792     Jamie L. Smith     smith jamie     NaN   Male
#
#       Races    Jurisdiction State Abbreviation Sub Jurisdiction  \
# 5049  Black       Tennessee                 TN  Hamilton County
# 5253  White           Texas                 TX  Angelina County
# 6980  White  North Carolina                 NC      Wake County
# 6981  White  North Carolina                 NC    Durham County
# 8152  Black  North Carolina                 NC  Buncombe County
#
#                      County and State Region  Year Multi-sentence identifier  \
# ...
